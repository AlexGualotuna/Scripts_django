# %%
#!pip install xlrd

# %%
archivo = "Jupyter/Universidad Americana (UAME)/Data-UAME.xls"

# %% [markdown]
# Se insertan extras que solo se necesita una vez

# %%
f = open('./Universidad Americana (UAME)/0. Extras.txt', 'w')

sql = """            
        insert into dara_mallas_mode
        (name, code, company_id)
        values 
            ('Presencial', 'P', 4),
            ('Online', 'L', 4);\n
            
        insert into dara_mallas_subject_class_name
        (name, company_id)
        values ('Carrera', 4);\n
        
        insert into dara_mallas_group_rule
        (name, company_id)
        values 
            ('A-100', 4),
            ('B-100', 4),
            ('C-100', 4);\n
        
        insert into dara_mallas_uec_credit
        (name, credit_hr_ind, credit_hr_low, credit_hr_high, company_id)
        values
            (0, NULL, 0.000, 0.000, 4),
            (1, NULL, 1.000, 0.000, 4),
            (2, NULL, 2.000, 0.000, 4),
            (3, NULL, 3.000, 0.000, 4),
            (4, NULL, 4.000, 0.000, 4),
            (5, NULL, 5.000, 0.000, 4);\n
            
        insert into dara_mallas_billed
        (name, bill_hr_ind, bill_hr_low, bill_hr_high, company_id)
        values
            (0, NULL, 0.000, 0.000, 4),
            (1, NULL, 1.000, 0.000, 4),
            (2, NULL, 2.000, 0.000, 4),
            (3, NULL, 3.000, 0.000, 4),
            (4, NULL, 4.000, 0.000, 4),
            (5, NULL, 5.000, 0.000, 4);\n
    """ 
f.write(sql)

f.close()

# %% [markdown]
# 0.1 +++++++++++++++++++++++++++++++++++STVTRMT++++++++++++++++++++++++++++
# Se insertan semestres, trimestral, etc...

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="STVTRMT")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/0-1. Journey.txt','w')
for i ,item in df.iterrows():
    sql = """
            insert into dara_mallas_journey
            (name, code, company_id)
            values ('%s', '%s', 4);\n
        """%(item['STVTRMT_DESC'],item['STVTRMT_CODE'])
    f.write(sql)
f.close()

# %% [markdown]
# 0.2 +++++++++++++++++++++++++++++++++++STVTERM++++++++++++++++++++++++++++
# Se insertan los periodos

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="STVTERM")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/0-2 Period.txt','w')
df['STVTERM_CODE'] = df['STVTERM_CODE'].astype(str).str.zfill(6)
for i ,item in df.iterrows():
    sql = """
            insert into dara_mallas_period
            (name, description, company_id)
            values ('%s', '%s', 4);\n
        """%(item['STVTERM_CODE'],item['STVTERM_DESC'])
    f.write(sql)
f.close()

# %% [markdown]
# 1. +++++++++++++++++++++++++++++++++++STVCOLL++++++++++++++++++++++++++++
# Se insertan las facultades

# %%
import os
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="STVCOLL")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/1. College.txt','w')
for i ,item in df.iterrows():
    sql = """
            insert into dara_mallas_college
            (name, name_short, code, name_en, company_id)
            values ('%s', '%s', '%s', NULL, 4);\n
        """%(item['DESCRIPCION_FACULTAD'],item['STVCOLL_DESC'],item['STVCOLL_CODE'])
    f.write(sql)
f.close()

# %% [markdown]
# 2. +++++++++++++++++++++++++++++++++++STVLEVL++++++++++++++++++++++++++++
# Se insertar los grados Ej: pregrado, posgrado, etc.

# %%
import os
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="STVLEVL")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/2. Grade.txt','w')
for i ,item in df.iterrows():
    sql = """
            insert into dara_mallas_grade
            (name, description, company_id)
            values ('%s', '%s',4);\n
        """%(item['STVLEVL_DESC'],item['STVLEVL_CODE'])
    f.write(sql)
f.close()

# %% [markdown]
# 3. +++++++++++++++++++++++++++++++++++STVCAMP++++++++++++++++++++++++++++
# Se insertan los campus

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="STVCAMP")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/3. Campus.txt','w')
for i ,item in df.iterrows():
    sql = """
            insert into dara_mallas_campus
            (name, code, company_id)
            values ('%s', '%s',4);\n
        """%(item['STVCAMP_DESC'],item['STVCAMP_CODE'])
    f.write(sql)
f.close()

# %% [markdown]
# 3.5 +++++++++++++++++++++++++++++++++++STVDEPT++++++++++++++++++++++++++++
# Se insertan los departamentos

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=0,sheet_name="STVDEPT")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/3-5. Departamentos.txt','w')
for i ,item in df.iterrows():
    sql = """
            insert into dara_mallas_subject_department
            (code, name, company_id)
            values ('%s', '%s',4);\n
        """%(item['sigla'],item['descripcion'])
    f.write(sql)
f.close()

# %% [markdown]
# 4. +++++++++++++++++++++++++++++++++++STVMAJR++++++++++++++++++++++++++++
# Se inserta saes_code

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="STVMAJR")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/6-1. Majr.txt','w')
for i ,item in df.iterrows():
    sql = """
        insert into dara_mallas_specialization
            (name,
            color,
            program_id,
            saes_speciality_plan_code,
            company_id)
        select
            '%s',
            '#FFFFFF',
            pc.program_id,
            NULL,
            4
        from dara_mallas_program_code pc
        where pc.saes_code_id = (
                select id
                from dara_mallas_saes_code
                where name = '%s'
                and company_id = 4)
        and pc.company_id = 4;
        """ % (item['STVMAJR_DESC'], item['STVMAJR_CODE'])
    f.write(sql)
f.close()

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="STVMAJR")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/4. Saes_code.txt','w')
for i ,item in df.iterrows():
    sql = """
            insert into dara_mallas_saes_code
            (name, company_id)
            values ('%s', 4);\n
        """%(item['STVMAJR_CODE'])
    f.write(sql)
f.close()

# %% [markdown]
# 5.  +++++++++++++++++++++++++++++++++++STVDEGC++++++++++++++++++++++++++++
# Se agrega los titulos, ejemplo: Licenciatura, diplomado, etc.

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="STVDEGC")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/5. Banner_grade.txt','w')
for i ,item in df.iterrows():
    sql = """
            insert into dara_mallas_banner_grade
            (code, name, company_id)
            values ('%s', '%s', 4);\n
        """%(item['STVDEGC_CODE'],item['STVDEGC_DESC'])
    f.write(sql)
f.close()

# %% [markdown]
# 6. +++++++++++++++++++++++++++++++++++SMRPRLE++++++++++++++++++++++++++++
# Se inserta los programas

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="SMRPRLE")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/6-5. update_program.txt','w')
for i ,item in df.iterrows():
    sql = """ 
            UPDATE dara_mallas_program
            SET college_id=(select id from dara_mallas_college where code='%s' and company_id=4)
            WHERE 
                id IN (select program_id from dara_mallas_program_code where name='%s' and company_id=4)
                AND company_id=4;\n
        """%(item['FACULTAD'], item['SMRPRLE_PROGRAM'])
    f.write(sql)
f.close()

# %% [markdown]
# 7. +++++++++++++++++++++++++++++++++++STVSUBJ++++++++++++++++++++++++++++
# Se inserta las materias

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="STVSUBJ")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/7. Subject_name.txt','w')
for i ,item in df.iterrows():
    sql = """
            insert into dara_mallas_subject_name
            (name, code, company_id)
            values ('%s', '%s', 4);\n
        """%(item['STVSUBJ_DESC'],item['STVSUBJ_CODE'])
    f.write(sql)
f.close()

# %% [markdown]
# 7.5. +++++++++++++++++++++++++++++++++++STVGMOD++++++++++++++++++++++++++++
# Modo de calificación

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="STVGMOD")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/7-5. Grade_mode.txt','w')
for i ,item in df.iterrows():
    sql = """
            insert into dara_mallas_grade_mode
            (name, description, grade_mode_line_subject_id, company_id)
            values ('%s', '%s', NULL, 4);\n
        """%(item['STVGMOD_CODE'],item['STVGMOD_DESC'])
    f.write(sql)
f.close()

# %% [markdown]
# 8. +++++++++++++++++++++++++++++++++++STVSCHD++++++++++++++++++++++++++++
# Se inserta schedule_class, ej: Teorico, practica, etc.

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="STVSCHD")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/8. Schedule_class.txt','w')
for i ,item in df.iterrows():
    sql = """
            insert into dara_mallas_schedule_class
            (name, code, company_id)
            values ('%s', '%s', 4);\n
        """%(item['STVSCHD_DESC'], item['STVSCHD_CODE'])
    f.write(sql)
f.close()

# %% [markdown]
# 8.1 +++++++++++++++++++++++++++++++++++STVSCHD++++++++++++++++++++++++++++
# Se inserta estados: Inactivo, activo

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="STVCSTA")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/8-1. Subject_status.txt','w')
for i ,item in df.iterrows():
    sql = """
            insert into dara_mallas_subject_status
            (name, description, company_id)
            values ('%s', '%s', 4);\n
        """%(item['STVCSTA_DESC'], item['STVCSTA_CODE'])
    f.write(sql)
f.close()

# %% [markdown]
# 9. +++++++++++++++++++++++++++++++++++SCBCRSE++++++++++++++++++++++++++++
# Se inserta schedule_class, ej: Teorico, practica, etc.

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18, sheet_name="SCBCRSE")

# Asegurar que el número tenga ceros a la izquierda (4 dígitos)
df['SCBCRSE_CRSE_NUMB'] = df['SCBCRSE_CRSE_NUMB'].astype(str).str.zfill(4)

f = open('./Universidad Americana (UAME)/9. Subject.txt', 'w')
for i, item in df.iterrows():

    # Concatenación final HSHM0002
    course_number = f"{item['SCBCRSE_SUBJ_CODE']}{item['SCBCRSE_CRSE_NUMB']}"

    sql = """
            insert into dara_mallas_subject
            (name, name_en, short_name, code, course_number, subject_name_id, new_subject, company_id)
            values (
            '%s', --name
            NULL,
            '%s', --short_name
            '%s', --code
            '%s', --course_number
            (SELECT id FROM dara_mallas_subject_name WHERE code = '%s' and company_id=4),
            NULL,
            4);\n
            
            insert into dara_mallas_subject_class
            (subject_class_id, subject_id, company_id)
            values (
                (select id from dara_mallas_subject_class_name where name = 'Carrera' and company_id = 4),
                (select id from dara_mallas_subject where code = '%s' and company_id = 4),
                4
            );\n
        """ % (
            item['SCBCRSE_TITLE'],
            item['SCBCRSE_TITLE'],
            course_number,
            item['SCBCRSE_CRSE_NUMB'],            
            item['SCBCRSE_SUBJ_CODE'],
            course_number
        )
    f.write(sql)
f.close()

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18, sheet_name="SCBCRSE")

# Asegurar que el número tenga ceros a la izquierda (4 dígitos)
df['SCBCRSE_CRSE_NUMB'] = df['SCBCRSE_CRSE_NUMB'].astype(str).str.zfill(4)
df['SCBCRSE_EFF_TERM'] = df['SCBCRSE_EFF_TERM'].astype(str).str.zfill(6)

f = open('./Universidad Americana (UAME)/9-1. Scacrse.txt', 'w')
for i, item in df.iterrows():
    sigla = f"{item['SCBCRSE_SUBJ_CODE']}{item['SCBCRSE_CRSE_NUMB']}"
    billed = (
        int(item['SCBCRSE_BILL_HR_LOW']) 
        if pd.notna(item['SCBCRSE_BILL_HR_LOW'])
        else 0
    )
    repeat_limit = (
        int(item['SCBCRSE_REPEAT_LIMIT'])
        if pd.notna(item['SCBCRSE_REPEAT_LIMIT'])
        else 0
    )
    
    total_hours = (
        int(item['SCBCRSE_LEC_HR_LOW'])
        if pd.notna(item['SCBCRSE_LEC_HR_LOW'])
        else 0
    )

    sql = """
            insert into dara_mallas_subject_scacrse
            (period_id, subject_id, college_id, area_id, status_id, uec_credit_id, billed_id, repeat_limit, face_to_face, academic_hours, lab_practicing_hours, additional_hours_whistle, total_academic_hours, application_hours, practicing_hours, community_service_hours, lab_application_hours, asisted_hours, autonomus_hours, learning_organization, tit_hours, hybrid, hybrid_academic_hours, hybrid_virtual_academic_hours, hybrid_lab_practicing_hours, hybrid_externship_hours, hybrid_additional_hours_whistle, hybrid_total_academic_hours, hybrid_application_hours, hybrid_practicing_hours, hybrid_community_service_hours, hybrid_lab_application_hours, hybrid_asisted_hours, hybrid_autonomus_hours, hybrid_tit_hours, online, online_academic_hours, online_application_hours, online_practicing_hours, online_community_service_hours, online_lab_application_hours, online_asisted_hours, online_autonomus_hours, online_sesions, online_tit_hours, total_hours, credits, teaching_credits, externship_credits, lab_credits, sesions, teaching_sesions, externship_sesions, lab_sesions, externship_hours, internship_hours, externship_weeks, lab_weeks, hours_validation, itinerary, elective, is_requisite_graduation, is_web, gpa, externship_application_hours, company_id)
            values (
            (select id from dara_mallas_period where name = '%s' and company_id = 4), --period_id
            (select id from dara_mallas_subject where code = '%s' and company_id = 4), --subject_id
            (select id from dara_mallas_college where code = '%s' and company_id = 4), --college_id
            (select id from dara_mallas_subject_department where code = '%s' and company_id = 4), --area_id
            (select id from dara_mallas_subject_status where description = '%s' and company_id = 4), --status_id
            (select id from dara_mallas_uec_credit where name = '%s' and company_id = 4), --uec_credit_id
            (select id from dara_mallas_billed where name = '%s' and company_id = 4), --billed_id
            '%s', --repeat_limit
            NULL, --face_to_face
            NULL, --academic_hours
            NULL, --lab_practicing_hours
            NULL, --additional_hours_whistle
            NULL, --total_academic_hours
            NULL, --application_hours
            NULL, --practicing_hours
            NULL, --community_service_hours
            NULL, --lab_application_hours
            NULL, --asisted_hours
            NULL, --autonomus_hours
            NULL, --learning_organization
            NULL, --tit_hours
            NULL, --hybrid
            NULL, --hybrid_academic_hours
            NULL, --hybrid_virtual_academic_hours
            NULL, --hybrid_lab_practicing_hours
            NULL, --hybrid_externship_hours
            NULL, --hybrid_additional_hours_whistle
            NULL, --hybrid_total_academic_hours
            NULL, --hybrid_application_hours
            NULL, --hybrid_practicing_hours
            NULL, --hybrid_community_service_hours
            NULL, --hybrid_lab_application_hours
            NULL, --hybrid_asisted_hours
            NULL, --hybrid_autonomus_hours
            NULL, --hybrid_tit_hours
            NULL, --online
            NULL, --online_academic_hours
            NULL, --online_application_hours
            NULL, --online_practicing_hours
            NULL, --online_community_service_hours
            NULL, --online_lab_application_hours
            NULL, --online_asisted_hours
            NULL, --online_autonomus_hours
            NULL, --online_sesions
            NULL, --online_tit_hours
            '%s', --total_hours
            '%s', --credits
            '%s', --teaching_credits
            NULL, --externship_credits
            NULL, --lab_credits
            '%s', --sesions
            '%s', --teaching_sesions
            NULL, --externship_sesions
            NULL, --lab_sesions
            NULL, --externship_hours
            NULL, --internship_hours
            NULL, --externship_weeks
            NULL, --lab_weeks
            NULL, --hours_validation
            NULL, --itinerary
            NULL, --elective
            NULL, --is_requisite_graduation
            NULL, --is_web
            true, --gpa
            NULL, --externship_application_hours
            4 --company_id
            );\n 
        """ % (
            item['SCBCRSE_EFF_TERM'],
            sigla,
            item['SCBCRSE_COLL_CODE'],
            item['SCBCRSE_DEPT_CODE'],
            item['SCBCRSE_CSTA_CODE'], #status
            item['SCBCRSE_CREDIT_HR_LOW'], #uec_credit
            billed, #billed
            repeat_limit, #repear_limit
            total_hours, #total_hours
            item['SCBCRSE_OTH_HR_LOW'], #credits
            item['SCBCRSE_OTH_HR_LOW'], #teaching_credits
            item['SCBCRSE_CONT_HR_LOW'], #sesions
            item['SCBCRSE_CONT_HR_LOW'] #teaching_sesions
        )
    f.write(sql)
f.close()

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="SCBCRSE")
#df = df.fillna("")
df['SCBCRSE_CRSE_NUMB'] = df['SCBCRSE_CRSE_NUMB'].astype(str).str.zfill(4)
df['SCBCRSE_EFF_TERM'] = df['SCBCRSE_EFF_TERM'].astype(str).str.zfill(6)
f = open('./Universidad Americana (UAME)/9-2. Update_name_scacrse.txt','w')
for i ,item in df.iterrows():
    sigla = f"{item['SCBCRSE_SUBJ_CODE']}{item['SCBCRSE_CRSE_NUMB']}"
    sql = """ 
            UPDATE dara_mallas_subject_scacrse
            SET name = (select s.code || ' - ' || s.name || ' / ' || p.name from dara_mallas_subject_scacrse sc
                join dara_mallas_subject s on s.id = sc.subject_id
                join dara_mallas_period p on p.id = sc.period_id
                where sc.period_id = (select id from dara_mallas_period where name = '%s' and company_id = 4)
                and subject_id = (select id from dara_mallas_subject where code = '%s' and company_id = 4)
                and sc.company_id=4)
            WHERE period_id = (select id from dara_mallas_period where name = '%s' and company_id = 4)
            and subject_id = (select id from dara_mallas_subject where code = '%s' and company_id = 4) 
            and company_id=4;\n 
        """%(item['SCBCRSE_EFF_TERM'], sigla, item['SCBCRSE_EFF_TERM'], sigla)
    f.write(sql)
f.close()

# %% [markdown]
# 10. +++++++++++++++++++++++++++++++++++SCRLEVL++++++++++++++++++++++++++++
# Se registra las materias en grade_line

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="SCRLEVL")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/10. Grade_line_subject.txt','w')
# Asegurar que el número tenga ceros a la izquierda (4 dígitos)
df['SCRLEVL_CRSE_NUMB'] = df['SCRLEVL_CRSE_NUMB'].astype(str).str.zfill(4)
df['SCRLEVL_EFF_TERM'] = df['SCRLEVL_EFF_TERM'].astype(str).str.zfill(6)

for i ,item in df.iterrows():
    subject = f"{item['SCRLEVL_SUBJ_CODE']}{item['SCRLEVL_CRSE_NUMB']}"
    
    sql = """
            insert into dara_mallas_grade_line_subject
            (subject_id, period_id, company_id)
            values (
                (select id from dara_mallas_subject where code = '%s' and company_id=4),
                (select id from dara_mallas_period where name = '%s' and company_id=4),
                4);\n
            
            insert into dara_mallas_grade_line
            (grade_id, grade_line_subject_id, company_id)
            values (
            (select id from dara_mallas_grade where description = '%s' and company_id=4),
            (select id from dara_mallas_grade_line_subject where 
            period_id = (select id from dara_mallas_period where name = '%s' and company_id=4) and subject_id = (select id from dara_mallas_subject where code = '%s' and company_id=4)),
            4);\n
        """%(subject, item['SCRLEVL_EFF_TERM'], item['SCRLEVL_LEVL_CODE'], item['SCRLEVL_EFF_TERM'], subject )
    f.write(sql)
f.close()

# %% [markdown]
# 11. +++++++++++++++++++++++++++++++++++SCRGMOD++++++++++++++++++++++++++++

# %%
import os
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="SCRGMOD")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/11. Grade_mode_line_subject.txt','w')
# Asegurar que el número tenga ceros a la izquierda (4 dígitos)
df['SCRGMOD_EFF_TERM'] = df['SCRGMOD_EFF_TERM'].astype(str).str.zfill(6)
df['SCRGMOD_CRSE_NUMB'] = df['SCRGMOD_CRSE_NUMB'].astype(str).str.zfill(4)

for i ,item in df.iterrows():
    subject = f"{item['SCRGMOD_SUBJ_CODE']}{item['SCRGMOD_CRSE_NUMB']}"
    
    sql = """
            insert into dara_mallas_grade_mode_line_subject
            (period_id, subject_id, company_id)
            values (
            (select id from dara_mallas_period where name = '%s' and company_id=4),
            (select id from dara_mallas_subject where code = '%s' and company_id=4),
            4);\n
            
            insert into dara_mallas_grade_mode_line
            (grade_mode_id, grade_mode_line_subject_id, company_id)
            values (
            (select id from dara_mallas_grade_mode where name = '%s' and company_id=4),
            (select id from dara_mallas_grade_mode_line_subject where 
            period_id = (select id from dara_mallas_period where name = '%s' and company_id=4) and subject_id = (select id from dara_mallas_subject where code = '%s' and company_id=4)),
            4);\n
        """%(item['SCRGMOD_EFF_TERM'], subject, item['SCRGMOD_GMOD_CODE'], item['SCRGMOD_EFF_TERM'], subject )
    f.write(sql)
f.close()

# %% [markdown]
# 12. +++++++++++++++++++++++++++++++++++SCRSCHD++++++++++++++++++++++++++++

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="SCRSCHD")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/12. Schedule_class_line.txt','w')

df['SCRSCHD_EFF_TERM'] = df['SCRSCHD_EFF_TERM'].astype(str).str.zfill(6) #periodo
df['SCRSCHD_CRSE_NUMB'] = df['SCRSCHD_CRSE_NUMB'].astype(str).str.zfill(4)
    
for i ,item in df.iterrows():
    subject = f"{item['SCRSCHD_SUBJ_CODE']}{item['SCRSCHD_CRSE_NUMB']}"
    sql = """
            INSERT INTO dara_mallas_schedule_class_line_subject
                (period_id, subject_id, company_id)
                SELECT
                    (SELECT id FROM dara_mallas_period WHERE name = '%s' and company_id = 4),
                    (SELECT id FROM dara_mallas_subject WHERE code = '%s' AND company_id = 4),
                    4
                WHERE EXISTS (
                    SELECT 1 FROM dara_mallas_subject WHERE code = '%s' AND company_id = 4)
                AND NOT EXISTS (
                    SELECT 1 FROM dara_mallas_schedule_class_line_subject scls
                    JOIN dara_mallas_subject sub ON sub.id = scls.subject_id
                    WHERE sub.code = '%s' AND scls.company_id = 4);\n

                
            insert into dara_mallas_schedule_class_line
            (schedule_class_id, "default", schedule_class_line_subject_id, company_id)
            values (
                (select id from dara_mallas_schedule_class where code = '%s' and company_id=4),
                NULL,
                (select id from dara_mallas_schedule_class_line_subject where 
                subject_id = (select id from dara_mallas_subject where code = '%s'and company_id = 4) and company_id=4), 
                4);\n
        """%(item['SCRSCHD_EFF_TERM'], subject, subject, subject, item['SCRSCHD_SCHD_CODE'], subject)
    f.write(sql)
f.close()

# %% [markdown]
# 13. +++++++++++++++++++++++++++++++++++SCBCRKY++++++++++++++++++++++++++++
#
# SE ELIMINA

# %% [markdown]
# 14. +++++++++++++++++++++++++++++++++++SCRCORQ++++++++++++++++++++++++++++

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="SCRCORQ")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/14. Corequisite.txt','w')

df['SCRCORQ_CRSE_NUMB'] = df['SCRCORQ_CRSE_NUMB'].astype(str).str.zfill(4)
df['SCRCORQ_CRSE_NUMB_CORQ'] = df['SCRCORQ_CRSE_NUMB_CORQ'].astype(str).str.zfill(4)
for i ,item in df.iterrows():
    subject = f"{item['SCRCORQ_SUBJ_CODE']}{item['SCRCORQ_CRSE_NUMB']}"
    subject2 = f"{item['SCRCORQ_SUBJ_CODE_CORQ']}{item['SCRCORQ_CRSE_NUMB_CORQ']}"
    
    sql = """
            insert into dara_mallas_corequisite_line
            (subject_id, period_id, company_id)
            values (
                (select id from dara_mallas_subject where code = '%s' and company_id=4), 
                (select id from dara_mallas_period where name = '%s' and company_id=4), 
                4);\n
            
            insert into dara_mallas_corequisite
            (corequisite_subject_id, corequisite_line_id, company_id)
            values (
            (select id from dara_mallas_subject where code = '%s' and company_id=4),
            (select id from dara_mallas_corequisite_line where 
                subject_id = (select id from dara_mallas_subject where code = '%s' and company_id=4) and 
                period_id = (select id from dara_mallas_period where name = '%s' and company_id = 4)),
            4);\n
        """%(subject, item['SCRCORQ_EFF_TERM'], subject2, subject, item['SCRCORQ_EFF_TERM'])
    f.write(sql)
f.close()

# %% [markdown]
# 15. +++++++++++++++++++++++++++++++++++SCRSYLN++++++++++++++++++++++++++++
#
# No se toma en cuenta por que son materias ya registradas de otra hoja

# %% [markdown]
# 16. +++++++++++++++++++++++++++++++++++SCRCLPP++++++++++++++++++++++++++++
# Prerequisitos

# %% [markdown]
# 17. +++++++++++++++++++++++++++++++++++SMRALIB++++++++++++++++++++++++++++
# Se insertan area

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="SMRALIB")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/17. Area.txt','w')
for i ,item in df.iterrows():
    sql = """
            insert into dara_mallas_area
            (name, code, company_id)
            values ('%s', '%s', 4);\n
        """%(item['SMRALIB_AREA_DESC'],item['SMRALIB_AREA'])
    f.write(sql)
f.close()

# %% [markdown]
# 18. +++++++++++++++++++++++++++++++++++SMBAGEN++++++++++++++++++++++++++++

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="SMBAGEN")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/18. Area_homologation.txt','w')
df['SMBAGEN_TERM_CODE_EFF'] = df['SMBAGEN_TERM_CODE_EFF'].astype(str).str.zfill(6)

for i ,item in df.iterrows():
    sql = """
            insert into dara_mallas_area_homologation
            (period_id, area_id, dinamic, file_name, company_id)
            values (
                (select id from dara_mallas_period where name = '%s' and company_id=4),
                (select id from dara_mallas_area where code = '%s' and company_id=4),
                NULL, NULL, 4);\n
        """%(item['SMBAGEN_TERM_CODE_EFF'],item['SMBAGEN_AREA'])
    f.write(sql)
f.close()

# %% [markdown]
# 19. +++++++++++++++++++++++++++++++++++SMRARUL++++++++++++++++++++++++++++

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="SMRARUL")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/19. Subject_rule.txt','w')

df['SMRARUL_TERM_CODE_EFF'] = df['SMRARUL_TERM_CODE_EFF'].astype(str).str.zfill(6)
df['SMRARUL_CRSE_NUMB_LOW'] = df['SMRARUL_CRSE_NUMB_LOW'].astype(str).str.zfill(4)
    
for i ,item in df.iterrows():
    subject = f"{item['SMRARUL_SUBJ_CODE']}{item['SMRARUL_CRSE_NUMB_LOW']}"
    group = f"{item['SMRARUL_SET']}-{item['SMRARUL_SUBSET']}"
    sql = """
            INSERT INTO dara_mallas_subject_rule
                (period_id, subject_id, area_id, company_id)
            SELECT
                (SELECT id FROM dara_mallas_period WHERE name = '%s' AND company_id=4),
                (SELECT id FROM dara_mallas_subject WHERE code = '%s' AND company_id=4),
                (SELECT id FROM dara_mallas_area WHERE code = '%s' AND company_id=4),
                4
            WHERE NOT EXISTS (
                SELECT 1
                FROM dara_mallas_subject_rule sr
                WHERE sr.period_id = (SELECT id FROM dara_mallas_period WHERE name = '%s' AND company_id=4)
                AND sr.subject_id = (SELECT id FROM dara_mallas_subject WHERE code = '%s' AND company_id=4)
                AND sr.area_id   = (SELECT id FROM dara_mallas_area WHERE code = '%s' AND company_id=4)
            );\n

                
            insert into dara_mallas_homologation
            (homologation_subject_id, subject_attributes_id, group_id, condition, test, min_score, max_score, rule_min_score_id, subject_rule_id, subject_rule_subject_id, company_id)
            values (
                (select id from dara_mallas_subject where code = '%s' and company_id=4),
                NULL,
                (select id from dara_mallas_group_rule where name = '%s' and company_id=4),
                NULL, --condition
                NULL, --test
                NULL, --min_score
                NULL, --max_score
                NULL, --rule_min_score_id
                (select id from dara_mallas_subject_rule where 
                    period_id = (select id from dara_mallas_period where name = '%s' and company_id=4) and 
                    subject_id = (select id from dara_mallas_subject where code = '%s' and company_id=4) and
                    area_id = (select id from dara_mallas_area where code = '%s' and company_id=4)
                ), --subject_rule_id
                NULL, --subject_rule_subject_id
                4);\n --company_id
        """%(item['SMRARUL_TERM_CODE_EFF'],item['SMRARUL_KEY_RULE'], item['SMRARUL_AREA'],item['SMRARUL_TERM_CODE_EFF'],item['SMRARUL_KEY_RULE'], item['SMRARUL_AREA'], subject, group, item['SMRARUL_TERM_CODE_EFF'],item['SMRARUL_KEY_RULE'], item['SMRARUL_AREA'])
    f.write(sql)
f.close()

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="SMRACAA")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/19-1. Subject_inherit_area.txt','w')
df['SMRACAA_TERM_CODE_EFF'] = df['SMRACAA_TERM_CODE_EFF'].astype(str).str.zfill(6)

for i ,item in df.iterrows():
    sql = """
            insert into dara_mallas_subject_inherit
                (subject_id, subject_scacrse_id, grade_mode_line_subject_id, grade_line_subject_id, schedule_class_line_subject_id, company_id)
                select
                    s.id,
                    sc.id,
                    (select gmls.id
                        from dara_mallas_grade_mode_line_subject gmls
                        where gmls.subject_id = s.id
                        and gmls.company_id = 4),
                    (select gls.id
                        from dara_mallas_grade_line_subject gls
                        where gls.subject_id = s.id
                        and gls.company_id = 4),
                    (select scls.id
                        from dara_mallas_schedule_class_line_subject scls
                        where scls.subject_id = s.id
                        and scls.company_id = 4),
                    4
                from dara_mallas_subject s
                join dara_mallas_subject_scacrse sc
                    on sc.subject_id = s.id
                and sc.company_id = 4
                where s.code = '%s'
                and s.company_id = 4
                and not exists (
                        select 1
                        from dara_mallas_subject_inherit si
                        where si.subject_id = s.id
                        and si.subject_scacrse_id = sc.id
                        and si.company_id = 4);\n
            
            insert into dara_mallas_subject_inherit_area
            (subject_inherit_id, line_order, study_field_id, organization_unit_id, area_homologation_id, company_id)
            values (
                (select id from dara_mallas_subject_inherit where subject_id = (select id from dara_mallas_subject where code = '%s' and company_id = 4) and company_id = 4), -- aqui no deberia ir limit
                NULL,
                NULL,
                NULL,
                (select id from dara_mallas_area_homologation where area_id = (select id from dara_mallas_area where code ='%s' and company_id = 4) 
                    and period_id = (select id from dara_mallas_period where name = '%s' and company_id = 4)
                    and company_id = 4),
                4);\n
                
            insert into dara_mallas_subject_inherit_homologation
            (subject_rule_id, subject_inherit_id, subject_inherit_history_id, company_id)
            values(
                (select id from dara_mallas_subject_rule where 
                    subject_id = (select id from dara_mallas_subject where code = '%s' and company_id = 4) 
                    and period_id = (select id from dara_mallas_period where name = '%s' and company_id = 4)
                    and area_id = (select id from dara_mallas_area where code = '%s' and company_id = 4)
                    and company_id = 4),
                (select id from dara_mallas_subject_inherit where subject_id = (select id from dara_mallas_subject where code = '%s' and company_id = 4) and company_id = 4),
                NULL,
                4);\n            
        """%(item['SMRACAA_RULE'], item['SMRACAA_RULE'], item['SMRACAA_AREA'], item['SMRACAA_TERM_CODE_EFF'], item['SMRACAA_RULE'], item['SMRACAA_TERM_CODE_EFF'],item['SMRACAA_AREA'], item['SMRACAA_RULE'])
    f.write(sql)
f.close()

# %% [markdown]
# 20. +++++++++++++++++++++++++++++++++++SMBARUL++++++++++++++++++++++++++++

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="SMBARUL")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/20. Condition_homologation.txt','w')
df['SMBARUL_TERM_CODE_EFF'] = df['SMBARUL_TERM_CODE_EFF'].astype(str).str.zfill(6)

for i ,item in df.iterrows():
    sql = """ 
            UPDATE dara_mallas_homologation
            SET condition='%s'
            WHERE subject_rule_id = (select id from dara_mallas_subject_rule where 
                subject_id = (select id from dara_mallas_subject where code = '%s' and company_id=4) and
                period_id = (select id from dara_mallas_period where name = '%s' and company_id=4) and
                area_id = (select id from dara_mallas_area where code = '%s' and company_id=4))
            AND company_id=4;\n
        """%(item['SMBARUL_REQ_NUMB_COND'], item['SMBARUL_KEY_RULE'],item['SMBARUL_TERM_CODE_EFF'], item['SMBARUL_AREA'])
    f.write(sql)
f.close()

# %% [markdown]
# 21. +++++++++++++++++++++++++++++++++++SOBCURR++++++++++++++++++++++++++++
# Ingreso del study_plan

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="SOBCURR")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/21. Study_plan.txt','w')
df['SOBCURR_TERM_CODE_INIT'] = df['SOBCURR_TERM_CODE_INIT'].astype(str).str.zfill(6)

for i ,item in df.iterrows():
    sql = """
        INSERT INTO dara_mallas_study_plan
            (
                program_id,
                period_id,
                description,
                grade_id,
                banner_grade_id,
                with_students,
                study_plan_class_id,
                area_id,
                graduation_profile,
                graduation_profile_en,
                state,
                file_name,
                plan_template_file_name,
                prerequisite_file_name,
                corequisite_file_name,
                homologation_file_name,
                campus_id,
                hours_max,
                hours_min,
                coordinator_id,
                mallas_web,
                sniese_program_id,
                redesign_code_id,
                study_plan_stop,
                historic_file_name,
                company_id,
                total_credits,
                total_hours
            )
            SELECT
                p.id AS program_id,
                per.id AS period_id,
                NULL,
                g.id AS grade_id,
                bg.id AS banner_grade_id,
                NULL,
                NULL,
                NULL,
                NULL,
                NULL,
                NULL,
                NULL,
                NULL,
                NULL,
                NULL,
                NULL,
                c.id AS campus_id,
                NULL,
                NULL,
                NULL,
                NULL,
                NULL,
                NULL,
                NULL,
                NULL,
                4,
                NULL,
                NULL
            FROM dara_mallas_program p
            JOIN dara_mallas_program_code pc
                ON pc.program_id = p.id
                AND pc.name = '%s'
                AND pc.company_id = 4
            JOIN dara_mallas_period per
                ON per.name = '%s'
                AND per.company_id = 4
            JOIN dara_mallas_grade g
                ON g.description = '%s'
                AND g.company_id = 4
            JOIN dara_mallas_banner_grade bg
                ON bg.code = '%s'
                AND bg.company_id = 4
            JOIN dara_mallas_campus c
                ON c.code = '%s'
                AND c.company_id = 4
            WHERE p.period_id = per.id
            AND p.company_id = 4;
            
        """%(
                item['SOBCURR_PROGRAM'],
                item['SOBCURR_TERM_CODE_INIT'],
                item['SOBCURR_LEVL_CODE'],
                item['SOBCURR_DEGC_CODE'],
                item['SOBCURR_CAMP_CODE']
            )
    f.write(sql)
f.close()

# %% [markdown]
# 22. +++++++++++++++++++++++++++++++++++SMRPAAP++++++++++++++++++++++++++++
# Ingreso del study_plan_line

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="SMRPAAP")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/22. Study_plan_line.txt','w')
df['SMRPAAP_TERM_CODE_EFF'] = df['SMRPAAP_TERM_CODE_EFF'].astype(str).str.zfill(6)

for i ,item in df.iterrows():
    sql = """
            INSERT INTO dara_mallas_study_plan_line
                (line_order,
                area_homologation_id,
                study_plan_id,
                company_id
            )
            SELECT
                '%s' AS line_order,
                ah.id AS area_homologation_id,
                sp.id AS study_plan_id,
                4 AS company_id
            FROM dara_mallas_study_plan sp

            JOIN dara_mallas_program p
                ON p.id = sp.program_id
            AND p.company_id = 4

            JOIN dara_mallas_program_code pc
                ON pc.program_id = p.id
            AND pc.company_id = 4
            AND pc.name = '%s'

            JOIN dara_mallas_area_homologation ah
                ON ah.area_id = (
                    SELECT id
                    FROM dara_mallas_area
                    WHERE code = '%s'
                    AND company_id = 4
                )
            AND ah.period_id = (
                    SELECT id
                    FROM dara_mallas_period
                    WHERE name = '%s'
                    AND company_id = 4
                )
            AND ah.company_id = 4

            WHERE sp.period_id = (
                    SELECT id
                    FROM dara_mallas_period
                    WHERE name = '%s'
                    AND company_id = 4
            )
            AND sp.company_id = 4

            AND NOT EXISTS (
                SELECT 1
                FROM dara_mallas_study_plan_line spl
                WHERE spl.study_plan_id = sp.id
                AND spl.area_homologation_id = ah.id
                AND spl.company_id = 4
            );

        """%(
    item['SMRPAAP_AREA_PRIORITY'],   # line_order
    item['SMRPAAP_PROGRAM'],         # program_code
    item['SMRPAAP_AREA'],            # area_code
    item['SMRPAAP_TERM_CODE_EFF'],   # period (area_homologation)
    item['SMRPAAP_TERM_CODE_EFF']    # period (study_plan)
)        
    f.write(sql)
f.close()

# %% [markdown]
# 23. +++++++++++++++++++++++++++++++++++SMBPGEN++++++++++++++++++++++++++++
# Specialization major

# %% [markdown]
# No considerar de momento

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="SMBPGEN")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/23. Specialization_majr.txt','w')
df['SMBPGEN_TERM_CODE_EFF'] = df['SMBPGEN_TERM_CODE_EFF'].astype(str).str.zfill(6)

for i ,item in df.iterrows():
    program_code = str(item['SMBPGEN_PROGRAM']).strip()
    last_4 = program_code[-4:]
    if last_4.startswith('P'):
        saes_code = last_4[1:]
    else:
        saes_code = last_4
    sql = """
            INSERT INTO dara_mallas_specialization_major
                (
                    name,
                    "number",
                    code,
                    specialization_id,
                    saes_code_id,
                    company_id
                )
                SELECT
                    '%s' AS name,
                    0 AS "number",
                    0 AS code,
                    s.id AS specialization_id,
                    sc.id AS saes_code_id,
                    4 AS company_id
                FROM dara_mallas_specialization s
                JOIN dara_mallas_program p
                    ON p.id = s.program_id
                    AND p.name = '%s'
                    AND p.description = '%s'
                    AND p.period_id = (
                        SELECT id
                        FROM dara_mallas_period
                        WHERE name = '%s'
                        AND company_id = 4
                    )
                    AND p.company_id = 4
                JOIN dara_mallas_saes_code sc
                    ON sc.name = '%s'
                    AND sc.company_id = 4
                WHERE s.company_id = 4
                AND NOT EXISTS (
                    SELECT 1
                    FROM dara_mallas_specialization_major sm
                    WHERE sm.name = '%s'
                    AND sm.specialization_id = s.id
                    AND sm.saes_code_id = sc.id
                    AND sm.company_id = 4
                );
        """%(saes_code, item['NOMBRE_LARGO'], item['NOMBRE_TITULO'], item['SMBPGEN_TERM_CODE_EFF'], saes_code, saes_code)
    f.write(sql)
f.close()

# %%
import pandas as pd

df = pd.read_excel("/home/odoo/Documentos/DESARROLLO/%s"%(archivo),header=18,sheet_name="SMBPGEN")
#df = df.fillna("")
f = open('./Universidad Americana (UAME)/6. Program_posible.txt','w')
df['SMBPGEN_TERM_CODE_EFF'] = df['SMBPGEN_TERM_CODE_EFF'].astype(str).str.zfill(6)
for i ,item in df.iterrows():
    program_code = str(item['SMBPGEN_PROGRAM']).strip()
    last_4 = program_code[-4:]

    if last_4.startswith('P'):
        saes_code = last_4[1:]
    else:
        saes_code = last_4
    sql = """
        INSERT INTO dara_mallas_program
        (name, name_en, long_name, description, program_min_pga, college_id,
        duration_type, period_id, program_min_cali, company_id)
        SELECT
            '%s',
            NULL,
            '%s',
            '%s',
            0,
            NULL,
            'PERÍODOS ACADÉMICOS',
            (SELECT id FROM dara_mallas_period WHERE name = '%s' AND company_id = 4),
            NULL,
            4
        WHERE NOT EXISTS (
            SELECT 1
            FROM dara_mallas_program p
            WHERE p.name = '%s'
            AND p.description = '%s'
            AND p.period_id = (
                    SELECT id FROM dara_mallas_period
                    WHERE name = '%s' AND company_id = 4)
            AND p.company_id = 4);\n

        INSERT INTO dara_mallas_program_code
        (name, type, journey_id, mode_id, saes_code_id, program_id, company_id)
        VALUES (
            '%s',
            'UAME',
            (SELECT id FROM dara_mallas_journey WHERE name='CUATRIMESTRAL' AND company_id=4),
            (SELECT id FROM dara_mallas_mode WHERE code='%s' AND company_id=4),
            (SELECT id FROM dara_mallas_saes_code WHERE name='%s' AND company_id=4),
            (SELECT id FROM dara_mallas_program
            WHERE name='%s'
            AND period_id = (SELECT id FROM dara_mallas_period WHERE name = '%s' AND company_id = 4)
            AND description='%s'
            AND company_id=4),
            4
        );\n
        """ % (
            item['NOMBRE_LARGO'], item['NOMBRE_LARGO'], item['NOMBRE_TITULO'],
            item['SMBPGEN_TERM_CODE_EFF'],
            item['NOMBRE_LARGO'], item['NOMBRE_TITULO'], item['SMBPGEN_TERM_CODE_EFF'],
            program_code, program_code[5], saes_code,
            item['NOMBRE_LARGO'], item['SMBPGEN_TERM_CODE_EFF'], item['NOMBRE_TITULO']
        )
    f.write(sql)
f.close()
