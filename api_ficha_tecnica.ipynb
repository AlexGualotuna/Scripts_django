# %%
# !pip install requests

# %%
import requests
 
#url = "http://20.161.37.4:8004/api/v1/ficha"
url = "http://10.111.7.65:8073/api/v1/ficha"
#url = "https://pruebasmallas.udla.edu.ec/edu_ia/api/v1/ficha"
payload = {"program_name": "MAESTRÍA EN CIBERSEGURIDAD","modalidad":"Online","program_code":"UDLA1P264"}
#payload = {"program_name": "CyberSeguridad","modalidad":"Online","program_code":"UDLA1H070"}
 
response = requests.post(url, json=payload)
print("Status code:", response.status_code)
print("Response:", response.text)
# Out:
# Status code: 404
# Response: <!doctype html>
# <html lang=en>
# <title>404 Not Found</title>
# <h1>Not Found</h1>
# <p>The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.</p>
